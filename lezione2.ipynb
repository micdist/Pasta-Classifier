# %% [markdown]
# <a href="https://colab.research.google.com/github/micdist/fast.ai/blob/main/lezione2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hide
# !pip install -U fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
key = os.environ.get('AZURE_SEARCH_KEY', '902511d642d44ccd983cdf8ca50331a3')

# %%
search_images_bing
# Out:
# <function fastbook.search_images_bing>

# %%
results = search_images_bing(key, 'grizzly bear')
ims = results.attrgot('content_url')
len(ims)
# Out:
# 150

# %%
ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %%
dest = "images\grizzly.jpg"
download_url(ims[0], dest)

# %%
im = Image.open(dest)
im.to_thumb(512,512)
# Out:
# <PIL.Image.Image image mode=RGB size=433x512 at 0x7F71CE5EB8D0>

# %%
os.path.abspath('images')
# Out:
# '/content/images'

# %%
os
